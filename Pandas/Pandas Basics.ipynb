# %%
#imporing the library

import pandas as pd

# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
import numpy as np

# %%
data_frame = pandas.readcsv("diabetes.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 data_frame = pandas.readcsv("diabetes.csv")
#
# NameError: name 'pandas' is not defined

# %%
from sklearn.datasets import load_boston

# %%
pip install scikit-learn

# %%
from sklearn.datasets import load_boston

# %%
from sklearn.datasets import load_boston

# %%
dict1 = { "name":['Mridudl', 'rohan','skilff','sihn'],
         "marks":[10,20,30,40],
         "city":["rangpir","lmao","ded","jeez"]
        }

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#       name  marks     city
# 0  Mridudl     10  rangpir
# 1    rohan     20     lmao
# 2   skilff     30      ded
# 3     sihn     40     jeez

# %%
df.to_csv("lmao.csv")

# %%
df.head(2)
# Out:
#       name  marks     city
# 0  Mridudl     10  rangpir
# 1    rohan     20     lmao

# %%
df.tail(2)
# Out:
#      name  marks  city
# 2  skilff     30   ded
# 3    sihn     40  jeez

# %%
df.to_csv("lmaowoi.csv",index=False)

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   25.000000
# std    12.909944
# min    10.000000
# 25%    17.500000
# 50%    25.000000
# 75%    32.500000
# max    40.000000

# %%
#reading external file
mri = pd.read_csv("mridul.csv")

# %%
mri
# Out:
#    Train No  speed     city
# 0       432     10  rangpir
# 1     32423     20     lmao
# 2     24234     30      ded
# 3      4324     40     jeez

# %%
#changing value
mri['speed'][0]=100
# Out:
# C:\Users\MRIDUL\AppData\Local\Temp\ipykernel_2664\2584963880.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   mri['speed'][0]=100
# ...

# %%
mri
# Out:
#    Train No  speed     city
# 0       432    100  rangpir
# 1     32423     20     lmao
# 2     24234     30      ded
# 3      4324     40     jeez

# %%
mri['speed'][0]=100
# Out:
# C:\Users\MRIDUL\AppData\Local\Temp\ipykernel_2664\3128692643.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   mri['speed'][0]=100
# ...

# %%
mri
# Out:
#    Train No  speed     city
# 0       432    100  rangpir
# 1     32423     20     lmao
# 2     24234     30      ded
# 3      4324     40     jeez

# %%
mri.to_csv("change.csv")

# %%
#changing the index
mri.index = ['1st','2nd','3rd','4th']

# %% [raw]
# mri

# %%
mri
# Out:
#      Train No  speed     city
# 1st       432    100  rangpir
# 2nd     32423     20     lmao
# 3rd     24234     30      ded
# 4th      4324     40     jeez

# %%
mri
# Out:
#      Train No  speed     city
# 1st       432    100  rangpir
# 2nd     32423     20     lmao
# 3rd     24234     30      ded
# 4th      4324     40     jeez

# %%
#series in pandas
ser = pd.Series(np.random.rand(34))
type(ser)
ser
# Out:
# 0     0.460107
# 1     0.718859
# 2     0.175864
# 3     0.797096
# 4     0.784651
# 5     0.618196
# 6     0.756698
# 7     0.376516
# 8     0.006213
# 9     0.899887
# 10    0.813953
# 11    0.934711
# 12    0.718300
# 13    0.028168
# 14    0.027101
# 15    0.014486
# 16    0.882782
# 17    0.443635
# 18    0.917830
# 19    0.517580
# 20    0.672841
# 21    0.577345
# 22    0.072558
# 23    0.676087
# 24    0.671652
# 25    0.064983
# 26    0.386289
# 27    0.522042
# 28    0.238933
# 29    0.336578
# 30    0.363288
# 31    0.860190
# 32    0.273489
# 33    0.975437
# dtype: float64

# %%
#dataframe creating
newdf = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))

# %%
newdf.head()
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0.480021    0.497576    0.500760    0.488473    0.483131
# std      0.299110    0.286149    0.294722    0.301536    0.288947
# min      0.002305    0.001802    0.004170    0.000505    0.005153
# 25%      0.204084    0.239966    0.246445    0.238338    0.229067
# 50%      0.475580    0.492944    0.498759    0.460216    0.472347
# 75%      0.730196    0.759632    0.770532    0.766008    0.735559
# max      0.997405    0.983557    0.997670    0.999251    0.995331

# %%
newdf[0][0] = "mri"
# Out:
# C:\Users\MRIDUL\AppData\Local\Temp\ipykernel_2664\2261544394.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newdf[0][0] = "mri"
# ...

# %%
newdf
# Out:
#             0         1         2         3         4
# 0         mri  0.025446  0.266247  0.864068  0.205884
# 1    0.487359  0.618350  0.409190  0.729407  0.901231
# 2    0.525682  0.111820  0.288871  0.867365  0.178359
# 3    0.422996  0.227935  0.385305  0.097438  0.613467
# 4    0.447545  0.473362  0.129064  0.721109  0.974189
# ..        ...       ...       ...       ...       ...
# 329  0.837464  0.360754  0.947480  0.890708  0.267674
# 330  0.974889  0.036080  0.273650  0.332943  0.670620
# 331  0.551982  0.662147  0.378562  0.861122  0.425545
# 332  0.023164  0.044930  0.574559  0.057542  0.695520
# 333  0.441306  0.943802  0.765320  0.830333  0.677340
#
# [334 rows x 5 columns]

# %%
newdf.index
newdf.columns
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
#converting a dataframe to np
newdf.to_numpy()
# Out:
# array([['mri', 0.02544584868479305, 0.2662466022752803,
#         0.8640682150467737, 0.20588406926076486],
#        [0.4873589328667737, 0.618350476812023, 0.4091903879522967,
#         0.729406847871864, 0.9012308049726333],
#        [0.5256817696888147, 0.11182038893057211, 0.28887100168960933,
#         0.8673654324264805, 0.17835879636668173],
#        ...,
#        [0.5519821784151437, 0.6621471290849223, 0.37856212990994353,
#         0.8611224338278566, 0.4255450332552033],
#        [0.023164304179608908, 0.0449298054337105, 0.5745586416464976,
#         0.05754247471570395, 0.6955196111718069],
#        [0.4413061955984995, 0.9438022395537393, 0.7653199587031824,
#         0.8303329518627989, 0.6773399491364768]], dtype=object)

# %%
#sorting the index
newdf.sort_index(axis=0,ascending=False)
# Out:
#             0         1         2         3         4
# 333  0.441306  0.943802  0.765320  0.830333  0.677340
# 332  0.023164  0.044930  0.574559  0.057542  0.695520
# 331  0.551982  0.662147  0.378562  0.861122  0.425545
# 330  0.974889  0.036080  0.273650  0.332943  0.670620
# 329  0.837464  0.360754  0.947480  0.890708  0.267674
# ..        ...       ...       ...       ...       ...
# 4    0.447545  0.473362  0.129064  0.721109  0.974189
# 3    0.422996  0.227935  0.385305  0.097438  0.613467
# 2    0.525682  0.111820  0.288871  0.867365  0.178359
# 1    0.487359  0.618350  0.409190  0.729407  0.901231
# 0         mri  0.025446  0.266247  0.864068  0.205884
#
# [334 rows x 5 columns]

# %%
#view
newdf2=newdf

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0       mri  0.025446  0.266247  0.864068  0.205884
# 1  0.487359  0.618350  0.409190  0.729407  0.901231
# 2  0.525682  0.111820  0.288871  0.867365  0.178359
# 3  0.422996  0.227935  0.385305  0.097438  0.613467
# 4  0.447545  0.473362  0.129064  0.721109  0.974189

# %%
newdf2[0][0]=131231
newdf.head()
# Out:
#           0         1         2         3         4
# 0    131231  0.025446  0.266247  0.864068  0.205884
# 1  0.487359  0.618350  0.409190  0.729407  0.901231
# 2  0.525682  0.111820  0.288871  0.867365  0.178359
# 3  0.422996  0.227935  0.385305  0.097438  0.613467
# 4  0.447545  0.473362  0.129064  0.721109  0.974189

# %%
#copy // change hoyna
newdf2 = newdf.copy()
newdf2[0][0]=53452
newdf.head()
# Out:
# C:\Users\MRIDUL\AppData\Local\Temp\ipykernel_2664\1719938571.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newdf2[0][0]=53452
# ...

# %%
#value add or change
newdf.loc[0,0]=213
newdf.head(2)
# Out:
#           0         1         2         3         4
# 0       213  0.025446  0.266247  0.864068  0.205884
# 1  0.487359  0.618350  0.409190  0.729407  0.901231

# %%
#deleting a column or row
newdf = newdf.drop(1,axis=0) #row theke ekta shorabe
newdf.head()
# Out:
#           0         1         2         3         4
# 0       213  0.025446  0.266247  0.864068  0.205884
# 2  0.525682  0.111820  0.288871  0.867365  0.178359
# 3  0.422996  0.227935  0.385305  0.097438  0.613467
# 4  0.447545  0.473362  0.129064  0.721109  0.974189
# 5  0.846853  0.711361  0.157731  0.440639  0.168792

# %%
#specific row or col
newdf.loc[[0,2],[2,4]]
# Out:
#           2         4
# 0  0.266247  0.205884
# 2  0.288871  0.178359

# %%
#condition check
newdf.loc[(newdf[3]<0.3) & (newdf[4]>0.5)]
# Out:
#             0         1         2         3         4
# 3    0.422996  0.227935  0.385305  0.097438  0.613467
# 7    0.331257  0.421414  0.893435  0.053361  0.562524
# 8    0.110647  0.062049  0.973750  0.044995  0.697199
# 9    0.172939  0.540199  0.600654  0.224421  0.939302
# 30   0.828772  0.226001  0.369965  0.091222  0.647056
# 43   0.238545  0.512771  0.546575  0.257198  0.993237
# 50   0.412785  0.846975  0.982037  0.100069  0.824748
# 56   0.373935  0.848009  0.797556  0.204153  0.818962
# 62   0.579947  0.397647  0.802814  0.100601  0.965402
# 65   0.366027  0.383838  0.154904  0.153070  0.937428
# 68    0.56023  0.074015  0.066693  0.095224  0.888869
# 78   0.477828  0.345689  0.303678  0.251564  0.959134
# 82   0.598124  0.796449  0.767089  0.023559  0.542381
# 83    0.42385  0.977074  0.718683  0.059950  0.714926
# 88   0.033607  0.647399  0.648155  0.206731  0.911599
# 105  0.321882  0.662692  0.186561  0.280657  0.628872
# ...
